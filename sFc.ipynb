# %% [markdown]
# <a href="https://colab.research.google.com/github/Vishal4002/project/blob/main/sFc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df_train=pd.read_csv('/content/train.csv')
df_test=pd.read_csv('/content/test.csv')

# %%
df_train.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
df_test.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# 0               Tier 1  Supermarket Type1
# 1               Tier 2  Supermarket Type1
# 2               Tier 3      Grocery Store
# 3               Tier 2  Supermarket Type1
# 4               Tier 3  Supermarket Type3

# %%
print(df_train.shape,df_test.shape)
# Out:
# (8523, 12) (5681, 11)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df_train['Item_Type'].unique()
# Out:
# array(['Dairy', 'Soft Drinks', 'Meat', 'Fruits and Vegetables',
#        'Household', 'Baking Goods', 'Snack Foods', 'Frozen Foods',
#        'Breakfast', 'Health and Hygiene', 'Hard Drinks', 'Canned',
#        'Breads', 'Starchy Foods', 'Others', 'Seafood'], dtype=object)

# %%
df_train.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
# List of numerical features:
numerical = df_train.select_dtypes(include = ['int64', 'Int64','float64']).dtypes.index
numerical
# Out:
# Index(['Item_Weight', 'Item_Visibility', 'Item_MRP',
#        'Outlet_Establishment_Year', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
cat_features = df_train.select_dtypes(include = ['object']).dtypes.index
cat_features
# Out:
# Index(['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier',
#        'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type'],
#       dtype='object')

# %%
df_train['source'] = 'train'
df_test['source'] = 'test'
df=pd.concat([df_train,df_test], ignore_index=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14204 entries, 0 to 14203
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            14204 non-null  object
#  1   Item_Weight                11765 non-null  float64
#  2   Item_Fat_Content           14204 non-null  object
#  3   Item_Visibility            14204 non-null  float64
#  4   Item_Type                  14204 non-null  object
#  5   Item_MRP                   14204 non-null  float64
#  6   Outlet_Identifier          14204 non-null  object
#  7   Outlet_Establishment_Year  14204 non-null  int64
#  8   Outlet_Size                10188 non-null  object
#  9   Outlet_Location_Type       14204 non-null  object
#  10  Outlet_Type                14204 non-null  object
#  11  Item_Outlet_Sales          8523 non-null   float64
#  12  source                     14204 non-null  object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 1.4+ MB

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  2439
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  4016
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales            5681
# source                          0
# dtype: int64

# %%
df['Item_Weight'].fillna(df['Item_Weight'].mean(),inplace=True)

# %%
df['Outlet_Size'].value_counts()
# Out:
# Outlet_Size
# Medium    4655
# Small     3980
# High      1553
# Name: count, dtype: int64

# %%
df['Outlet_Size'].fillna('Medium', inplace=True)

# %%
df['Item_Type']
# Out:
# 0         4
# 1        14
# 2        10
# 3         6
# 4         9
#          ..
# 14199    13
# 14200    15
# 14201     8
# 14202     3
# 14203     3
# Name: Item_Type, Length: 14204, dtype: int64

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                     0
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales            5681
# source                          0
# dtype: int64

# %%
df['Item_Visibility'].value_counts()
# Out:
# Item_Visibility
# 0.000000    879
# 0.076841      3
# 0.077011      3
# 0.077169      3
# 0.076792      3
#            ...
# 0.162572      1
# 0.014826      1
# 0.058034      1
# 0.043786      1
# 0.104720      1
# Name: count, Length: 13006, dtype: int64

# %%
df['Item_Visibility'].replace(0.0,value=np.nan,inplace=True)

# %%
df['Item_Visibility']=df['Item_Visibility'].fillna(df.groupby('Item_Identifier')['Item_Visibility'].transform('mean'))

# %%
df['Item_Fat_Content'].replace({'LF':'Low Fat','reg':'Regular','low fat':'Low Fat'},inplace=True)

# %%
test_pred = df.loc[df['source'] == 'test']
test_pred.drop(['Item_Outlet_Sales','source'],axis=1,inplace=True)
test_pred.head()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8523           FDW58    20.750000          Low Fat         0.007565
# 8524           FDW14     8.300000          Regular         0.038428
# 8525           NCN55    14.600000          Low Fat         0.099575
# 8526           FDQ58     7.315000          Low Fat         0.015388
# 8527           FDY38    12.792854          Regular         0.118599
#
#         Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 8523  Snack Foods  107.8622            OUT049                       1999
# 8524        Dairy   87.3198            OUT017                       2007
# 8525       Others  241.7538            OUT010                       1998
# 8526  Snack Foods  155.0340            OUT017                       2007
# 8527        Dairy  234.2300            OUT027                       1985
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type
# 8523      Medium               Tier 1  Supermarket Type1
# 8524      Medium               Tier 2  Supermarket Type1
# 8525      Medium               Tier 3      Grocery Store
# 8526      Medium               Tier 2  Supermarket Type1
# 8527      Medium               Tier 3  Supermarket Type3

# %%
from sklearn.preprocessing import LabelEncoder
categ = ['Item_Fat_Content', 'Item_Type', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type']
le = LabelEncoder()
df[categ] = df[categ].apply(le.fit_transform)

# %%
df.drop(['Item_Identifier','Outlet_Identifier'],axis=1,inplace=True)

# %%
df
# Out:
#        Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0             9.30                 0         0.016047          4  249.8092
# 1             5.92                 1         0.019278         14   48.2692
# 2            17.50                 0         0.016760         10  141.6180
# 3            19.20                 1         0.022930          6  182.0950
# 4             8.93                 0         0.014670          9   53.8614
# ...            ...               ...              ...        ...       ...
# 14199        10.50                 1         0.013496         13  141.3154
# 14200         7.60                 1         0.142991         15  169.1448
# 14201        10.00                 0         0.073529          8  118.7440
# 14202        15.30                 1         0.098200          3  214.6218
# 14203         9.50                 1         0.104720          3   79.7960
#
#        Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  \
# 0                           1999            1                     0
# 1                           2009            1                     2
# 2                           1999            1                     0
# 3                           1998            1                     2
# 4                           1987            0                     2
# ...                          ...          ...                   ...
# 14199                       1997            2                     0
# 14200                       2009            1                     2
# 14201                       2002            1                     1
# 14202                       2007            1                     1
# 14203                       2002            1                     1
#
#        Outlet_Type  Item_Outlet_Sales source
# 0                1          3735.1380  train
# 1                2           443.4228  train
# 2                1          2097.2700  train
# 3                0           732.3800  train
# 4                1           994.7052  train
# ...            ...                ...    ...
# 14199            1                NaN   test
# 14200            2                NaN   test
# 14201            1                NaN   test
# 14202            1                NaN   test
# 14203            1                NaN   test
#
# [14204 rows x 11 columns]

# %%
train = df.loc[df['source'] == 'train']
test = df.loc[df['source'] == 'test']

# %%
train.drop(['source'],axis=1,inplace=True)
test.drop(['Item_Outlet_Sales','source'],axis=1,inplace=True)

# %%
train.head()
# Out:
#    Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0         9.30                 0         0.016047          4  249.8092
# 1         5.92                 1         0.019278         14   48.2692
# 2        17.50                 0         0.016760         10  141.6180
# 3        19.20                 1         0.022930          6  182.0950
# 4         8.93                 0         0.014670          9   53.8614
#
#    Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  Outlet_Type  \
# 0                       1999            1                     0            1
# 1                       2009            1                     2            2
# 2                       1999            1                     0            1
# 3                       1998            1                     2            0
# 4                       1987            0                     2            1
#
#    Item_Outlet_Sales
# 0          3735.1380
# 1           443.4228
# 2          2097.2700
# 3           732.3800
# 4           994.7052

# %%
test.head()
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 8523    20.750000                 0         0.007565         13  107.8622
# 8524     8.300000                 1         0.038428          4   87.3198
# 8525    14.600000                 0         0.099575         11  241.7538
# 8526     7.315000                 0         0.015388         13  155.0340
# 8527    12.792854                 1         0.118599          4  234.2300
#
#       Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  \
# 8523                       1999            1                     0
# 8524                       2007            1                     1
# 8525                       1998            1                     2
# 8526                       2007            1                     1
# 8527                       1985            1                     2
#
#       Outlet_Type
# 8523            1
# 8524            1
# 8525            0
# 8526            1
# 8527            3

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,accuracy_score

# %%
x = train.drop(columns="Item_Outlet_Sales")
y = train["Item_Outlet_Sales"]
X_train, X_test, y_train, y_test = train_test_split(x, y,test_size=0.2, random_state = 0)

# %%
model_comparison={}

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=400,max_depth=6,min_samples_leaf=100,n_jobs=4)
rf.fit(X_train,y_train)

y_pred = rf.predict(X_test)
y_pred
# Out:
# array([2605.45987783, 1320.28498205, 2133.602216  , ..., 4033.31745064,
#         204.0429164 , 5689.22114984])

# %%
model_comparison['Random Forest'] = [rf.score(X_train,y_train)*100,r2_score(y_test,y_pred)*100]

print("Random Forest\n\nAccuracy: {}%".format(round(rf.score(X_train,y_train)*100)))
print("r2 score: {}%".format(round(r2_score(y_test,y_pred)*100)))
# Out:
# Random Forest
#
# Accuracy: 61%
# r2 score: 59%

# %%
from xgboost import XGBRegressor

xgb = XGBRegressor(n_estimators = 100, learning_rate=0.05)
xgb.fit(X_train, y_train)

y_pred = xgb.predict(X_test)
y_pred
# Out:
# array([2639.2336 , 1639.5369 , 2321.186  , ..., 4653.376  ,  203.85124,
#        5898.958  ], dtype=float32)

# %%
model_comparison['XGBoost Regressor'] = [xgb.score(X_train,y_train)*100,r2_score(y_test,y_pred)*100]

print("XGBoost Regressor\n\nAccuracy: {}%".format(round(xgb.score(X_train,y_train)*100)))
print("r2 score: {}%".format(round(r2_score(y_test,y_pred)*100)))
# Out:
# XGBoost Regressor
#
# Accuracy: 68%
# r2 score: 58%

# %%
pred = xgb.predict(test)

# %%
test_pred["Predicted_Item_Outlet_Sale"] = pred
test_pred
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8523            FDW58    20.750000          Low Fat         0.007565
# 8524            FDW14     8.300000          Regular         0.038428
# 8525            NCN55    14.600000          Low Fat         0.099575
# 8526            FDQ58     7.315000          Low Fat         0.015388
# 8527            FDY38    12.792854          Regular         0.118599
# ...               ...          ...              ...              ...
# 14199           FDB58    10.500000          Regular         0.013496
# 14200           FDD47     7.600000          Regular         0.142991
# 14201           NCO17    10.000000          Low Fat         0.073529
# 14202           FDJ26    15.300000          Regular         0.098200
# 14203           FDU37     9.500000          Regular         0.104720
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 8523          Snack Foods  107.8622            OUT049
# 8524                Dairy   87.3198            OUT017
# 8525               Others  241.7538            OUT010
# 8526          Snack Foods  155.0340            OUT017
# 8527                Dairy  234.2300            OUT027
# ...                   ...       ...               ...
# 14199         Snack Foods  141.3154            OUT046
# 14200       Starchy Foods  169.1448            OUT018
# 14201  Health and Hygiene  118.7440            OUT045
# 14202              Canned  214.6218            OUT017
# 14203              Canned   79.7960            OUT045
#
#        Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8523                        1999      Medium               Tier 1
# 8524                        2007      Medium               Tier 2
# 8525                        1998      Medium               Tier 3
# 8526                        2007      Medium               Tier 2
# 8527                        1985      Medium               Tier 3
# ...                          ...         ...                  ...
# 14199                       1997       Small               Tier 1
# 14200                       2009      Medium               Tier 3
# 14201                       2002      Medium               Tier 2
# 14202                       2007      Medium               Tier 2
# 14203                       2002      Medium               Tier 2
#
#              Outlet_Type  Predicted_Item_Outlet_Sale
# 8523   Supermarket Type1                 1550.945557
# 8524   Supermarket Type1                 1369.170166
# 8525       Grocery Store                  554.519653
# 8526   Supermarket Type1                 2309.480713
# 8527   Supermarket Type3                 6217.856934
# ...                  ...                         ...
# 14199  Supermarket Type1                 2303.540771
# 14200  Supermarket Type2                 2472.330811
# 14201  Supermarket Type1                 1778.420898
# 14202  Supermarket Type1                 3409.264648
# 14203  Supermarket Type1                 1364.401855
#
# [5681 rows x 12 columns]

# %%
ls=[]
for i in test.columns:
    s = float(input(f"Enter the {i}:"))
    ls.append(s)
# Out:
# Enter the Item_Weight:15
# Enter the Item_Fat_Content:0
# Enter the Item_Visibility:3
# Enter the Item_Type:3
# Enter the Item_MRP:100
# Enter the Outlet_Establishment_Year:2028
# Enter the Outlet_Size:6
# Enter the Outlet_Location_Type:3
# Enter the Outlet_Type:3

# %%
xgb.predict(np.array(ls).reshape(1,-1))
# Out:
# array([1564.7815], dtype=float32)
